# %% [markdown]
# # <center> GRUPO 3   </center>
# ###  <center> Edward Calderon </center>
# ### <center> Jacob Arcila cardenas  </center>
# ### <center> Mateo arango montoya  </center>
# ### <center> Ivan camilo bravo lasso  </center>

# %% [markdown]
# # MODULO I

# %%
#Punto 1
#Literal a)

import random
from matplotlib import pyplot as plt 
import numpy as np
import cv2

img = cv2.cvtColor(cv2.imread('res/imagen.jpg'), cv2.COLOR_BGR2RGB)
#Se crea la imagen copia
img_add = np.zeros(img.shape, np.uint8)

q = 0; w = 0; e = -255
#Se sustituyen los valores de cada canal de la copia por los valores modificados de la imagen original
img_add[:,0:100:,0] = cv2.add(img[:,0:100,0], q)
img_add[:,0:100,1] = cv2.add(img[:,0:100,1], w)
img_add[:,0:100,2] = cv2.add(img[:,0:100,2], e)

q = -255; w = 0; e = 0
#Se sustituyen los valores de cada canal de la copia por los valores modificados de la imagen original
img_add[:,100:200:,0] = cv2.add(img[:,100:200,0], q)
img_add[:,100:200,1] = cv2.add(img[:,100:200,1], w)
img_add[:,100:200,2] = cv2.add(img[:,100:200,2], e)

q = 0; w = -255; e = -255
#Se sustituyen los valores de cada canal de la copia por los valores modificados de la imagen original
img_add[:,200:300:,0] = cv2.add(img[:,200:300,0], q)
img_add[:,200:300,1] = cv2.add(img[:,200:300,1], w)
img_add[:,200:300,2] = cv2.add(img[:,200:300,2], e)

q = -255; w = 0; e = -255
#Se sustituyen los valores de cada canal de la copia por los valores modificados de la imagen original
img_add[:,300:400,0] = cv2.add(img[:,300:400,0], q)
img_add[:,300:400,1] = cv2.add(img[:,300:400,1], w)
img_add[:,300:400,2] = cv2.add(img[:,300:400,2], e)
plt.imshow(img_add)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-f2dabe58acf7> in <module>()
#       7 import cv2
#       8
# ----> 9 img = cv2.cvtColor(cv2.imread('res/imagen.jpg'), cv2.COLOR_BGR2RGB)
#      10 #Se crea la imagen copia
#      11 img_add = np.zeros(img.shape, np.uint8)
#
# error: OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
img = cv2.imread("res/colores.png", cv2.IMREAD_COLOR)
img_rgb  = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

img_rgb  = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_R = img_rgb[:,:,0]
img_G = img_rgb[:,:,1]
img_B = img_rgb[:,:,2]
img_lab  = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
img_L = img_lab[:,:,0]
img_A =  img_lab[:,:,1]
img_B = img_lab[:,:,2]

img_xyz  = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_X = img_xyz[:,:,0]
img_Y =  img_xyz[:,:,1]
img_Z = img_xyz[:,:,2]


fig, arreglo_plots = plt.subplots(6,2, figsize=(15, 25))
colors = ('r','g','b')
#Canal LAB
arreglo_plots[0,0].set_title('Canal L')
arreglo_plots[0,0].imshow(img_L, cmap="gray")
arreglo_plots[0,1].set_title('Histograma Canal L')
img_array_i = img_lab[:,:,0].ravel()
arreglo_plots[0,1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[0])

arreglo_plots[1,0].set_title('Canal A')
arreglo_plots[1,0].imshow(img_A, cmap="gray")
arreglo_plots[1,1].set_title('Histograma Canal A')
img_array_i = img_lab[:,:,1].ravel()
arreglo_plots[1,1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[1])
    
arreglo_plots[2,0].set_title('Canal B')
arreglo_plots[2,0].imshow(img_B, cmap="gray")
arreglo_plots[2,1].set_title('Histograma Canal B')
img_array_i = img_lab[:,:,2].ravel()
arreglo_plots[2,1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[2])

#Canal XYZ
arreglo_plots[3,0].set_title('Canal R')
arreglo_plots[3,0].imshow(img_X, cmap="gray")
arreglo_plots[3,1].set_title('Histograma Canal R')
img_array_i = img_xyz[:,:,0].ravel()
arreglo_plots[3,1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[0])

arreglo_plots[4,0].set_title('Canal G')
arreglo_plots[4,0].imshow(img_Y, cmap="gray")
arreglo_plots[4,1].set_title('Histograma Canal G')
img_array_i = img_xyz[:,:,1].ravel()
arreglo_plots[4,1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[1])
    
arreglo_plots[5,0].set_title('Canal B')
arreglo_plots[5,0].imshow(img_Z, cmap="gray")
arreglo_plots[5,1].set_title('Histograma Canal B')
img_array_i = img_xyz[:,:,2].ravel()
arreglo_plots[5,1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[2]);

# %% [markdown]
# # MODULO II

# %%
# Punto 1 :Lea la imagen "col.png" y la imagen "jap.png" que se encuentran en la carpeta "res", muestrelas con plt.imshow. NO es necesario mostrar sus histogramas.

#Imagen importadas

img1 = cv2.imread('res/col.png', cv2.IMREAD_COLOR)
img2 = cv2.imread('res/jap.png', cv2.IMREAD_COLOR)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

fig = plt.figure(figsize=(15,24))

plt.subplot(1,2,1)
plt.imshow(img1,cmap='gray')
plt.title("Imagen 1")

plt.subplot(1,2,2)
plt.imshow(img2,cmap='gray')
plt.title("Imagen 2")
# Out:
# Text(0.5, 1.0, 'Imagen 2')

# %% [markdown]
# ## a)  A continuación, se presenta una transformación sobre ambas imágenes
#
# <br> <center> $ G(x,y) = (1-k)*I1(x,y) + k*I2(x,y) $ </center> </br>
#
# <br> <center> $ 0 < k < 1 $ </center> </br>
#
# <ul> Realice un código que muestre esta transformación, posteriormente responda: </ul>
#
# <ul> <br> ¿Qué ocurre si k = 1, k = 0, k = 0.5? </br> </ul>

# %%
#Se multiplican los valores de cada canal de las imagenes por (1-K) unidades, con 0 < K < 1
#Para k =1

k = 0.5
p = (1-k)

#Se crea la imagen copia
img1_div = np.zeros(img1.shape, np.uint8)
img2_div = np.zeros(img2.shape, np.uint8)

#Se sustituyen los valores de cada canal de las copias por los valores modificados de la imagen original

#se multiplca por (1-k) la imagen 1
img1_div[:,:,0] = cv2.multiply(img1[:,:,0], p)
img1_div[:,:,1] = cv2.multiply(img1[:,:,1], p)
img1_div[:,:,2] = cv2.multiply(img1[:,:,2], p)


#se multiplca por k la imagen 2
img2_div[:,:,0] = cv2.multiply(img2[:,:,0], k)
img2_div[:,:,1] = cv2.multiply(img2[:,:,1], k)
img2_div[:,:,2] = cv2.multiply(img2[:,:,2], k)

#hacerlas del mismo tamaño para poderlas sumar

img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

#Indicamos el parámetro a que indica la importancia de cada imagen


#Mediante la T.Lineal, si a=1, tenemos la imagen 1 únicamente. Si a=0, obtenemos solo img2.
# Si 0<a<1 tendremos combinaciones ponderadas de las imágenes entrada
res = cv2.add(img2*k,img1*(1-k)).astype(np.uint8)


#Se realiza el arreglo de 2x2 para mostrar imagen modificada vs histogramas
fig, arreglo_plots = plt.subplots(1,4, figsize=(15, 3))
colors = ('r','g','b')

#Se le dan títulos a los cuadros, se imprimen la img 1 y su histograma
arreglo_plots[0].set_title('Imagen original')
arreglo_plots[0].imshow(img1, cmap="gray")
arreglo_plots[1].set_title('Histograma original')
for i,col in enumerate(colors):
    img_array_i = img1[:,:,i].ravel()
    arreglo_plots[1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[i])

arreglo_plots[2].set_title('Imagen modificada k=1')
arreglo_plots[2].imshow(img1_div, cmap="gray")
arreglo_plots[3].set_title('Histograma modificado k=1')
for i,col in enumerate(colors):
    img_array_i = img1_div[:,:,i].ravel()
    arreglo_plots[3].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[i])
    
fig,arreglo_plots2 = plt.subplots(1,4, figsize=(15, 3))
    
#Se le dan títulos a los cuadros, se imprimen la img2 y su histograma
arreglo_plots2[0].set_title('Imagen original')
arreglo_plots2[0].imshow(img2, cmap="gray")
arreglo_plots2[1].set_title('Histograma original')
for i,col in enumerate(colors):
    img_array_i = img2[:,:,i].ravel()
    arreglo_plots2[1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[i])

arreglo_plots2[2].set_title('Imagen modificada k=1')
arreglo_plots2[2].imshow(img2_div, cmap="gray")
arreglo_plots2[3].set_title('Histograma modificado k=1')
for i,col in enumerate(colors):
    img_array_i = img2_div[:,:,i].ravel()
    arreglo_plots2[3].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[i])    
    
fig,arreglo_plots3 = plt.subplots(1,2, figsize=(15, 3))

#Se le dan títulos a los cuadros, se imprimen la suma y su histograma
arreglo_plots3[0].set_title('Imagen suma')
arreglo_plots3[0].imshow(res, cmap="gray")
arreglo_plots3[1].set_title('Histograma suma')
for i,col in enumerate(colors):
    img_array_i = res[:,:,i].ravel()
    arreglo_plots3[1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[i])
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:47: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:55: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:66: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:74: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:85: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %%
#Se multiplican los valores de cada canal de las imagenes por (1-K) unidades, con 0 < K < 1
#Para k =1

k = 1
p = (1-k)

#Se crea la imagen copia
img1_div = np.zeros(img1.shape, np.uint8)
img2_div = np.zeros(img2.shape, np.uint8)

#Se sustituyen los valores de cada canal de las copias por los valores modificados de la imagen original

#se multiplca por (1-k) la imagen 1
img1_div[:,:,0] = cv2.multiply(img1[:,:,0], p)
img1_div[:,:,1] = cv2.multiply(img1[:,:,1], p)
img1_div[:,:,2] = cv2.multiply(img1[:,:,2], p)


#se multiplca por k la imagen 2
img2_div[:,:,0] = cv2.multiply(img2[:,:,0], k)
img2_div[:,:,1] = cv2.multiply(img2[:,:,1], k)
img2_div[:,:,2] = cv2.multiply(img2[:,:,2], k)

#hacerlas del mismo tamaño para poderlas sumar

img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

#Indicamos el parámetro a que indica la importancia de cada imagen


#Mediante la T.Lineal, si a=1, tenemos la imagen 1 únicamente. Si a=0, obtenemos solo img2.
# Si 0<a<1 tendremos combinaciones ponderadas de las imágenes entrada
res = cv2.add(img2*k,img1*(1-k)).astype(np.uint8)


#Se realiza el arreglo de 2x2 para mostrar imagen modificada vs histogramas
fig, arreglo_plots = plt.subplots(1,4, figsize=(15, 3))
colors = ('r','g','b')

#Se le dan títulos a los cuadros, se imprimen la img 1 y su histograma
arreglo_plots[0].set_title('Imagen original')
arreglo_plots[0].imshow(img1, cmap="gray")
arreglo_plots[1].set_title('Histograma original')
for i,col in enumerate(colors):
    img_array_i = img1[:,:,i].ravel()
    arreglo_plots[1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[i])

arreglo_plots[2].set_title('Imagen modificada k=1')
arreglo_plots[2].imshow(img1_div, cmap="gray")
arreglo_plots[3].set_title('Histograma modificado k=1')
for i,col in enumerate(colors):
    img_array_i = img1_div[:,:,i].ravel()
    arreglo_plots[3].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[i])
    
fig,arreglo_plots2 = plt.subplots(1,4, figsize=(15, 3))
    
#Se le dan títulos a los cuadros, se imprimen la img2 y su histograma
arreglo_plots2[0].set_title('Imagen original')
arreglo_plots2[0].imshow(img2, cmap="gray")
arreglo_plots2[1].set_title('Histograma original')
for i,col in enumerate(colors):
    img_array_i = img2[:,:,i].ravel()
    arreglo_plots2[1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[i])

arreglo_plots2[2].set_title('Imagen modificada k=1')
arreglo_plots2[2].imshow(img2_div, cmap="gray")
arreglo_plots2[3].set_title('Histograma modificado k=1')
for i,col in enumerate(colors):
    img_array_i = img2_div[:,:,i].ravel()
    arreglo_plots2[3].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[i])    
    
fig,arreglo_plots3 = plt.subplots(1,2, figsize=(15, 3))

#Se le dan títulos a los cuadros, se imprimen la img2 y su histograma
arreglo_plots3[0].set_title('Imagen suma')
arreglo_plots3[0].imshow(res, cmap="gray")
arreglo_plots3[1].set_title('Histograma suma')
for i,col in enumerate(colors):
    img_array_i = res[:,:,i].ravel()
    arreglo_plots3[1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[i])
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:47: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:55: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:66: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:74: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:85: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %% [markdown]
# # ¿Qué ocurre si k = 1, k = 0, k = 0.5?

# %% [raw]
# luego el k es el peso que tiene cada imagen en la suma ponderada si k = 1 la imagen 2 tendra mas peso en la suma y se vera solo la img 2 , y viciversa
# y si k = 0.5 tendran el mismo peso y se mesclaran en la misma proporcion

# %% [markdown]
# ## b)
#
# <br> Implemente la transformación: </br>
# # <center> $ G(x,y) = a*I1(x,y) + b $ </center>
#
# Donde I1(x,y) es la imagen "col.png", a & b son constantes.
# <br> ¿Qué ocurre si a=0 & b es cualquier valor? ¿Qué ocurre si a = 1 & b > 255? </br>
# <br> Experimente con algún valor arbitrario de a & b y explique su resultado.

# %%
a = 0
b = 60

#Se crea la imagen copia
img3_div = np.zeros(img1.shape, np.uint8)

#se multiplca por a
img3_div[:,:,0] = cv2.multiply(img1[:,:,0], a)
img3_div[:,:,1] = cv2.multiply(img1[:,:,1], a)
img3_div[:,:,2] = cv2.multiply(img1[:,:,2], a)

#se suma b

res2 = cv2.add(img3_div,b).astype(np.uint8)


fig,arreglo_plots4 = plt.subplots(1,2, figsize=(15, 3))

#Se le dan títulos a los cuadros, se imprimen la suma y su histograma
arreglo_plots4[0].set_title('Imagen suma')
arreglo_plots4[0].imshow(res2, cmap="gray")
arreglo_plots4[1].set_title('Histograma suma')
for i,col in enumerate(colors):
    img_array_i = res2[:,:,i].ravel()
    arreglo_plots4[1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[i])
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:26: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %% [raw]
# si a 0  no le da peso a la imagen y todo al canal rojo
# b es la intensidad del canal rojo

# %%
a = 1
b = 256

#Se crea la imagen copia
img3_div = np.zeros(img1.shape, np.uint8)

#se multiplca por a
img3_div[:,:,0] = cv2.multiply(img1[:,:,0], a)
img3_div[:,:,1] = cv2.multiply(img1[:,:,1], a)
img3_div[:,:,2] = cv2.multiply(img1[:,:,2], a)

#se suma b

res2 = cv2.add(img3_div,b).astype(np.uint8)


fig,arreglo_plots4 = plt.subplots(1,2, figsize=(15, 3))

#Se le dan títulos a los cuadros, se imprimen la suma y su histograma
arreglo_plots4[0].set_title('Imagen suma')
arreglo_plots4[0].imshow(res2, cmap="gray")
arreglo_plots4[1].set_title('Histograma suma')
for i,col in enumerate(colors):
    img_array_i = res2[:,:,i].ravel()
    arreglo_plots4[1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),normed=True, color=colors[i])
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:26: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %%
si a = 1 toma la imagen y satura de rojo segun la intencidad dada por b
